# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import geopandas as gp
import shapely
import fiona

# %matplotlib inline
plt.rcParams['figure.figsize'] = (20, 10)
saved_style_state = matplotlib.rcParams.copy()

# %%
if os.path.isfile("type-of-incident-by-local-government-area.xlsx"):
    filepath = "type-of-incident-by-local-government-area.xlsx"
    print "loading from file"

incident_data = pd.read_excel(filepath)
print "done"
# Out:
# loading from file
# done

# %%
incident_data.head()
# Out:
#   Local Government Area  Fire, explosions  \
# 0                Albury               197
# 1     Armidale Dumaresq               218
# 2              Ashfield                84
# 3                Auburn               228
# 4               Ballina                87
#
#    Non-fire rescue calls including animal rescues  \
# 0                                              41
# 1                                              26
# 2                                              61
# 3                                             183
# 4                                             142
#
#    Hazardous material incidents and other hazardous conditions  \
# 0                                                100
# 1                                                 41
# 2                                                112
# 3                                                340
# 4                                                 36
#
# ...

# %%
sep_incident_data = incident_data.drop(['Total primary incidents'], axis=1)
sep_incident_data = sep_incident_data.drop(['Local Government Area'], axis=1)
sep_incident_data.head()
# Out:
#    Fire, explosions  Non-fire rescue calls including animal rescues  \
# 0               197                                              41
# 1               218                                              26
# 2                84                                              61
# 3               228                                             183
# 4                87                                             142
#
#    Hazardous material incidents and other hazardous conditions  \
# 0                                                100
# 1                                                 41
# 2                                                112
# 3                                                340
# 4                                                 36
#
#    Storm, floods and other natural disasters and calls for assistance from other agencies  \
# 0                                                 24
# 1                                                 12
# ...

# %%
incident_data['Highest incident'] = sep_incident_data.idxmax(axis=1) 
incident_data.head()
# Out:
#   Local Government Area  Fire, explosions  \
# 0                Albury               197
# 1     Armidale Dumaresq               218
# 2              Ashfield                84
# 3                Auburn               228
# 4               Ballina                87
#
#    Non-fire rescue calls including animal rescues  \
# 0                                              41
# 1                                              26
# 2                                              61
# 3                                             183
# 4                                             142
#
#    Hazardous material incidents and other hazardous conditions  \
# 0                                                100
# 1                                                 41
# 2                                                112
# 3                                                340
# 4                                                 36
#
# ...
