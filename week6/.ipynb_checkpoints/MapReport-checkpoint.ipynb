# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import geopandas as gp
import shapely
import fiona

shp_file_name = "NSW_LOCALITY_POLYGON_shp.shp"
zip_file_name = "nswlocalitypolygonshp.zip"
web_file_path = ("http://data.gov.au/dataset/91e70237-d9d1-4719-a82f-e71b811154c6/resource/" 
                 "bf8b5180-fcea-44bd-bd76-af14cc4b0fe0/download/nswlocalitypolygonshp.zip")

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (20, 10)
saved_style_state = matplotlib.rcParams.copy()

# %%
if os.path.isfile("type-of-incident-by-local-government-area.xlsx"):
    filepath = "type-of-incident-by-local-government-area.xlsx"
    print "loading from file"

incident_data = pd.read_excel(filepath)
print "done"
# Out:
# loading from file
# done

# %%
incident_data.head()
# Out:
#   Local Government Area  Fire, explosions  \
# 0                Albury               197
# 1     Armidale Dumaresq               218
# 2              Ashfield                84
# 3                Auburn               228
# 4               Ballina                87
#
#    Non-fire rescue calls including animal rescues  \
# 0                                              41
# 1                                              26
# 2                                              61
# 3                                             183
# 4                                             142
#
#    Hazardous material incidents and other hazardous conditions  \
# 0                                                100
# 1                                                 41
# 2                                                112
# 3                                                340
# 4                                                 36
#
#    Storm, floods and other natural disasters and calls for assistance from other agencies  \
# 0                                                 24
# 1                                                 12
# 2                                                 30
# 3                                                 54
# 4                                                  8
#
#    Good intent calls  Other service calls  System initiated false alarms  \
# 0                 11                   97                            267
# 1                  4                   83                            228
# 2                 23                  155                            193
# 3                 46                  122                            935
# 4                  7                   45                            109
#
#    Malicious false calls  Other calls  Total primary incidents
# 0                     16           17                      770
# 1                     15            6                      633
# 2                      4           27                      689
# 3                     21           43                     1972
# 4                      3            8                      445

# %%
def unzip_zipfile(zipped_file_path, put_it_here="."):
    import zipfile
    zip_of_suburbs = zipfile.ZipFile(zipped_file_path, 'r')
    zip_of_suburbs.extractall(put_it_here)
    zip_of_suburbs.close()

# %%
# Get the data loaded. This is a bit complicated because it's online as a zip file.
# If we don't have it right now, we need to get it and unzip it.
if os.path.isfile(shp_file_name):
    print "loading from file"
else:
    if os.path.isfile(zip_file_name):
        print "unzipping"
        unzip_zipfile(zip_file_name)
    else:
        import requests
        print "loading from the internet"
        page = requests.get(web_file_path)
        with open(zip_file_name, 'wb') as z:
            z.write(page.content)
        unzip_zipfile(zip_file_name)

print "done"
# Out:
# loading from file
# done

# %%
incident_data['Local Government Area'] = incident_data['Local Government Area'].str.upper()
incident_data.head()
# Out:
#   Local Government Area  Fire, explosions  \
# 0                ALBURY               197
# 1     ARMIDALE DUMARESQ               218
# 2              ASHFIELD                84
# 3                AUBURN               228
# 4               BALLINA                87
#
#    Non-fire rescue calls including animal rescues  \
# 0                                              41
# 1                                              26
# 2                                              61
# 3                                             183
# 4                                             142
#
#    Hazardous material incidents and other hazardous conditions  \
# 0                                                100
# 1                                                 41
# 2                                                112
# 3                                                340
# 4                                                 36
#
#    Storm, floods and other natural disasters and calls for assistance from other agencies  \
# 0                                                 24
# 1                                                 12
# 2                                                 30
# 3                                                 54
# 4                                                  8
#
#    Good intent calls  Other service calls  System initiated false alarms  \
# 0                 11                   97                            267
# 1                  4                   83                            228
# 2                 23                  155                            193
# 3                 46                  122                            935
# 4                  7                   45                            109
#
#    Malicious false calls  Other calls  Total primary incidents
# 0                     16           17                      770
# 1                     15            6                      633
# 2                      4           27                      689
# 3                     21           43                     1972
# 4                      3            8                      445

# %%
explosion = incident_data.iloc[:, [0, 1]]
explosion_sorted = explosion.sort_values(by=['Fire, explosions'], ascending=0)
explosion_sorted.plot(x = 'Local Government Area', y = 'Fire, explosions', kind = 'bar')
explosion_sorted.head()
# Out:
#     Local Government Area  Fire, explosions
# 11              BLACKTOWN              1313
# 147            WOLLONGONG              1012
# 26           CAMPBELLTOWN               876
# 106               PENRITH               831
# 77         LAKE MACQUARIE               768

# %%
burbs = gp.GeoDataFrame.from_file(shp_file_name)
burbs.drop(["NSW_LOCA_1", "NSW_LOCA_3", "NSW_LOCA_4", "DT_RETIRE"], axis=1, inplace=True)
burbs
# Out:
#        DT_CREATE LC_PLY_PID  LOC_PID  NSW_LOCALI            NSW_LOCA_2  \
# 0     2015-09-03      25113  NSW1147  2015-11-10          CROYDON PARK
# 1     2015-09-03      25065  NSW2557  2015-11-10         MAYFIELD WEST
# 2     2015-09-03      25115   NSW797  2015-11-10               CAMPSIE
# 3     2011-11-22      16193  NSW4136  2012-02-04           WALLACETOWN
# 4     2015-09-03      24884   NSW812  2015-11-10            CANTERBURY
# 5     2015-09-03      24885  NSW1359  2015-11-10              EARLWOOD
# 6     2015-09-03      25102  NSW3578  2015-11-10           SILVERWATER
# 7     2015-09-03      24903  NSW1012  2015-11-10               CONCORD
# 8     2012-11-21      19660  NSW4098  2013-01-23               UTUNGUN
# 9     2015-09-03      24888   NSW161  2015-11-10               BALMAIN
# 10    2015-09-03      25101  NSW4391  2015-11-10        WOLLSTONECRAFT
# 11    2015-09-03      24909  NSW3339  2015-11-10              RANDWICK
# 12    2012-11-21      19669  NSW3304  2013-01-23                PUTNEY
# 13    2015-09-03      24941  NSW2370  2015-11-10               LITHGOW
# 14    2015-09-03      24793  NSW3819  2015-11-10       TEN MILE HOLLOW
# 15    2015-09-03      24750  NSW3961  2015-11-10               TOUKLEY
# 16    2015-09-03      24842  NSW1411  2015-11-10         ELERMORE VALE
# 17    2015-09-03      24966  NSW4177  2015-11-10          WARATAH WEST
# 18    2015-09-03      25067  NSW2553  2015-11-10              MAYFIELD
# 19    2013-03-07      20524  NSW2941  2013-04-30         NAUGHTONS GAP
# 20    2013-03-07      20525  NSW3013  2013-04-30          NORTH CASINO
# 21    2009-08-31      10755    NSW58  2012-02-04              ANGOURIE
# 22    2013-03-07      20278   NSW948  2013-04-30       CLOTHIERS CREEK
# 23    2013-03-07      20526  NSW2153  2013-04-30               KILLARA
# 24    2013-08-26      20978  NSW3812  2013-11-01           TEA GARDENS
# 25    2014-02-28      22177  NSW4216  2014-05-02             WATANOBBI
# 17            G       None          1
# 18            G       None          1
# 19            G       None          1
# 20            G       None          1
# 21            G       None          1
# 22            G       None          1
# 23            G       None          1
# 24            G       None          1
# 25            G       None          1
# 26            G       None          1
# 27            G       None          1
# 28            G       None          1
# 29            G       None          1
# ...         ...        ...        ...
# 4542          G       None          1
# 4543          G       None          1
# 4544          G       None          1
# 4545          G       None          1
# 4546          G       None          1
# 4547          G       None          1
# 4548          G       None          1
# 4549          G       None          1
# 4550          G       None          1
# 4551          G       None          1
# 4552          G       None          1
# 4553          G       None          1
# 4554          G       None          1
# 4555          G       None          1
# 4556          G       None          1
# 4557          G       None          1
# 4558          G       None          1
# 4559          G       None          1
# 4560          G       None          1
# 4561          G       None          1
# 4562          G       None          1
# 4563          G       None          1
# 4564          G       None          1
# 4565          G       None          1
# 4566          G       None          1
# 4567          G       None          1
# 4568          G       None          1
# 4569          G       None          1
# 4570          G       None          1
# 4571          G       None          1
#
#                                                geometry
# 0     POLYGON ((151.1170000066 -33.89151546943, 151....
# 1     POLYGON ((151.73344571654 -32.87974104891, 151...
# 2     POLYGON ((151.1072750656 -33.9017926364, 151.1...
# 3     POLYGON ((147.450924738497 -34.9651865379095, ...
# 4     POLYGON ((151.11758210952 -33.90297173141, 151...
# 5     POLYGON ((151.14016397916 -33.91626727655, 151...
# 6     POLYGON ((151.05436177755 -33.82846392023, 151...
# 7     POLYGON ((151.10074278046 -33.84456767407, 151...
# 8     POLYGON ((152.805912214383 -30.710969747357, 1...
# 9     POLYGON ((151.17562156594 -33.85249200252, 151...
# 10    POLYGON ((151.19807629946 -33.82565730712, 151...
# 11    POLYGON ((151.24494816991 -33.90276364158, 151...
# 12    POLYGON ((151.103975648739 -33.8198688082116, ...
# 13    POLYGON ((150.16401602681 -33.46429521354, 150...
# 14    POLYGON ((151.08347738449 -33.30937809235, 151...
# 15    POLYGON ((151.52092431325 -33.26270211175, 151...
# 16    POLYGON ((151.64974515585 -32.91191719162, 151...
# 17    POLYGON ((151.72094823452 -32.89469731473, 151...
# 18    POLYGON ((151.73914307867 -32.88838216408, 151...
# 19    POLYGON ((153.092520605859 -28.77822120793, 15...
# 20    POLYGON ((153.04949759941 -28.771097380804, 15...
# 21    POLYGON ((153.358426990787 -29.4679243076527, ...
# 22    POLYGON ((153.525611829269 -28.3202714163999, ...
# 23    POLYGON ((151.166490918879 -33.7548603863733, ...
# 24    POLYGON ((152.239009479516 -32.5758257492686, ...
# 25    POLYGON ((151.431536439044 -33.2612745172915, ...
# 26    POLYGON ((149.565820791471 -33.7433310321004, ...
# 27    POLYGON ((152.289818132683 -32.5877124257038, ...
# 28    POLYGON ((148.812844481261 -32.4482071825286, ...
# 29    POLYGON ((151.12841421855 -33.930596162384, 15...
# ...                                                 ...
# 4542  POLYGON ((149.567872511985 -33.4350285456144, ...
# 4543  POLYGON ((148.934175649829 -35.8740918233517, ...
# 4544  POLYGON ((151.488684382861 -33.1882689436323, ...
# 4545  POLYGON ((148.832931316768 -35.8480529411212, ...
# 4546  POLYGON ((151.160452575922 -33.8010246492233, ...
# 4547  POLYGON ((150.71981129711 -33.5883329751327, 1...
# 4548  POLYGON ((148.087390932569 -35.4233446971498, ...
# 4549  POLYGON ((147.931383101206 -35.5693160712899, ...
# 4550  POLYGON ((151.058229985818 -33.865212409748, 1...
# 4551  POLYGON ((150.915763895298 -33.7506662657258, ...
# 4552  POLYGON ((150.960996397269 -33.794984029415, 1...
# 4553  POLYGON ((150.810077784755 -33.7781408727431, ...
# 4554  POLYGON ((151.085152788167 -33.8440216153106, ...
# 4555  POLYGON ((150.980908946116 -33.8219016416202, ...
# 4556  POLYGON ((151.061771842476 -34.0128676585274, ...
# 4557  POLYGON ((151.032126410545 -34.022028334925, 1...
# 4558  POLYGON ((150.482691881696 -28.6766925374295, ...
# 4559  POLYGON ((153.136923608032 -28.3566206143998, ...
# 4560  POLYGON ((153.158926422507 -28.3097554579701, ...
# 4561  POLYGON ((152.858237375723 -31.0092077193635, ...
# 4562  POLYGON ((152.727669005261 -30.863397526544, 1...
# 4563  POLYGON ((151.871463898217 -32.2014561590752, ...
# 4564  POLYGON ((150.270141578531 -35.6170686975746, ...
# 4565  POLYGON ((148.527111512052 -36.3995897652578, ...
# 4566  POLYGON ((150.821452680692 -33.73648063325, 15...
# 4567  POLYGON ((151.090888067932 -34.0060578216855, ...
# 4568  POLYGON ((150.844916713512 -34.4130912309402, ...
# 4569  POLYGON ((152.020347839706 -30.4536618000862, ...
# 4570  POLYGON ((150.844129416132 -34.5417983206378, ...
# 4571  POLYGON ((153.340672484218 -28.9010299630706, ...
#
# [4572 rows x 9 columns]

# %%
def add_centroid(row):
    return row.geometry.centroid

burbs["centroid"] = burbs.apply(add_centroid, axis=1)

# %%
list_areas = list(incident_data['Local Government Area'])
list_areas
# Out:
# [u'ALBURY',
#  u'ARMIDALE DUMARESQ',
#  u'ASHFIELD',
#  u'AUBURN',
#  u'BALLINA',
#  u'BALRANALD',
#  u'BANKSTOWN',
#  u'BATHURST REGIONAL',
#  u'BEGA VALLEY',
#  u'BELLINGEN',
#  u'BERRIGAN',
#  u'BLACKTOWN',
#  u'BLAND',
#  u'BLAYNEY',
#  u'BLUE MOUNTAINS',
#  u'BOGAN',
#  u'BOMBALA',
#  u'BOOROWA',
#  u'BOTANY BAY',
#  u'BOURKE',
#  u'BREWARRINA',
#  u'BROKEN HILL',
#  u'BURWOOD',
#  u'BYRON',
#  u'CABONNE',
#  u'CAMDEN',
#  u'CAMPBELLTOWN',
#  u'CANADA BAY',
#  u'CANTERBURY',
#  u'CARRATHOOL',
#  u'CESSNOCK',
#  u'CLARENCE VALLEY',
#  u'COBAR',
#  u'COFFS HARBOUR',
#  u'CONARGO',
#  u'COOLAMON',
#  u'COOMA-MONARO',
#  u'COONAMBLE',
#  u'COOTAMUNDRA',
#  u'COROWA SHIRE',
#  u'COWRA',
#  u'DENILIQUIN',
#  u'DUBBO',
#  u'DUNGOG',
#  u'EUROBODALLA',
#  u'FAIRFIELD',
#  u'FORBES',
#  u'GILGANDRA',
#  u'GLEN INNES SEVERN',
#  u'GLOUCESTER',
#  u'GOSFORD',
#  u'GOULBURN MULWAREE',
#  u'GREATER HUME SHIRE',
#  u'GREATER TAREE',
#  u'GREAT LAKES',
#  u'GRIFFITH',
#  u'GUNDAGAI',
#  u'GUNNEDAH',
#  u'GUYRA',
#  u'GWYDIR',
#  u'HARDEN',
#  u'HAWKESBURY',
#  u'HAY',
#  u'HOLROYD',
#  u'HORNSBY',
#  u'HUNTERS HILL',
#  u'HURSTVILLE',
#  u'INDIGO',
#  u'INVERELL',
#  u'JERILDERIE',
#  u'JUNEE',
#  u'KEMPSEY',
#  u'KIAMA',
#  u'KOGARAH',
#  u'KU-RING-GAI',
#  u'KYOGLE',
#  u'LACHLAN',
#  u'LAKE MACQUARIE',
#  u'LANE COVE',
#  u'LEETON',
#  u'LEICHHARDT',
#  u'LISMORE',
#  u'LITHGOW',
#  u'LIVERPOOL',
#  u'LIVERPOOL PLAINS',
#  u'LOCKHART',
#  u'MAITLAND',
#  u'MANLY',
#  u'MARRICKVILLE',
#  u'MID-WESTERN REGIONAL',
#  u'MOREE PLAINS',
#  u'MOSMAN',
#  u'MURRAY',
#  u'MURRUMBIDGEE',
#  u'MUSWELLBROOK',
#  u'NAMBUCCA',
#  u'NARRABRI',
#  u'NARRANDERA',
#  u'NARROMINE',
#  u'NEWCASTLE',
#  u'NORTH SYDNEY',
#  u'OBERON',
#  u'ORANGE',
#  u'PALERANG',
#  u'PARKES',
#  u'PARRAMATTA',
#  u'PENRITH',
#  u'PITTWATER',
#  u'PORT MACQUARIE-HASTINGS',
#  u'PORT STEPHENS',
#  u'QUEANBEYAN',
#  u'RANDWICK',
#  u'RICHMOND VALLEY',
#  u'ROCKDALE',
#  u'RYDE',
#  u'SHELLHARBOUR',
#  u'SHOALHAVEN',
#  u'SINGLETON',
#  u'SNOWY RIVER',
#  u'STRATHFIELD',
#  u'SUTHERLAND SHIRE',
#  u'SYDNEY',
#  u'TAMWORTH REGIONAL',
#  u'TEMORA',
#  u'TENTERFIELD',
#  u'THE HILLS SHIRE',
#  u'TUMBARUMBA',
#  u'TUMUT SHIRE',
#  u'TWEED',
#  u'UPPER HUNTER SHIRE',
#  u'UPPER LACHLAN SHIRE',
#  u'URALLA',
#  u'URANA',
#  u'WAGGA WAGGA',
#  u'WAKOOL',
#  u'WALCHA',
#  u'WALGETT',
#  u'WARREN',
#  u'WARRINGAH',
#  u'WARRUMBUNGLE SHIRE',
#  u'WAVERLEY',
#  u'WEDDIN',
#  u'WELLINGTON',
#  u'WENTWORTH',
#  u'WILLOUGHBY',
#  u'WINGECARRIBEE',
#  u'WOLLONDILLY',
#  u'WOLLONGONG',
#  u'WOOLLAHRA',
#  u'WYONG',
# 836        None          1  POLYGON ((151.177713561619 -33.9634411614048, ...
# 3859       None          1  POLYGON ((146.45088313667 -29.84272813992, 146...
# 64         None          1  POLYGON ((146.816589282422 -29.6407759679861, ...
# 130        None          1  POLYGON ((141.41039481204 -31.74849403347, 141...
# 996        None          1  POLYGON ((151.101169923065 -33.8684355879607, ...
# 858        None          1  POLYGON ((150.69498187089 -34.04138897154, 150...
# 1498       None          1  POLYGON ((150.82412900235 -34.05704418575, 150...
# 1165       None          1  POLYGON ((151.117749727 -33.8630804975, 151.11...
# 4          None          1  POLYGON ((151.11758210952 -33.90297173141, 151...
# 663        None          1  POLYGON ((145.67825632163 -34.08410372465, 145...
# 2294       None          1  POLYGON ((151.4129415773 -32.80465273937, 151....
# 660        None          1  POLYGON ((145.71444148777 -31.20566378844, 145...
# 3065       None          1  POLYGON ((153.13291555271 -30.26188263368, 153...
# 3524       None          1  POLYGON ((145.3376866 -35.0937577606, 145.3360...
# 4013       None          1  POLYGON ((147.189973453353 -34.7484518489786, ...
# 2147       None          1  POLYGON ((148.2045817823 -30.68040233425, 148....
# ...         ...        ...                                                ...
# 3738       None          1  POLYGON ((151.00510015491 -33.80452056549, 151...
# 3009       None          1  POLYGON ((150.70985867999 -33.763928429, 150.7...
# 849        None          1  POLYGON ((151.32386855392 -33.58102397908, 151...
# 162        None          1  POLYGON ((152.05997892102 -32.64956921982, 152...
# 2617       None          1  POLYGON ((149.22871437562 -35.3426059788024, 1...
# 11         None          1  POLYGON ((151.24494816991 -33.90276364158, 151...
# 3585       None          1  POLYGON ((151.13049379911 -33.94314646914, 151...
# 480        None          1  POLYGON ((151.12535759108 -33.81631625753, 151...
# 1669       None          1  POLYGON ((150.86816226725 -34.56847529481, 150...
# 3271       None          1  POLYGON ((151.18222925608 -32.55546428431, 151...
# 420        None          1  POLYGON ((151.1009936733 -33.86857565014, 151....
# 3559       None          1  POLYGON ((151.21566791259 -33.8561913563, 151....
# 1532       None          1  POLYGON ((147.542916200629 -34.3590972992676, ...
# 2718       None          1  POLYGON ((152.17849926341 -28.94430799474, 152...
# 4052       None          1  POLYGON ((148.13407911315 -35.60466268401, 148...
# 3935       None          1  POLYGON ((151.61641868354 -30.6063845211, 151....
# 3881       None          1  POLYGON ((146.13676075045 -35.16003127784, 146...
# 1812       None          1  POLYGON ((147.361662001453 -35.0907372489718, ...
# 2997       None          1  POLYGON ((144.457495282 -35.3599164905, 144.46...
# 2151       None          1  POLYGON ((151.93588991236 -30.76164205839, 151...
# 1336       None          1  POLYGON ((148.12959594001 -29.45799853765, 148...
# 107        None          1  POLYGON ((147.775868844498 -31.5962158631032, ...
# 3612       None          1  POLYGON ((151.25360053487 -33.8964994690814, 1...
# 250        None          1  POLYGON ((148.934795204256 -32.5436498127353, ...
# 1616       None          1  POLYGON ((141.89630106932 -33.62737644965, 141...
# 4105       None          1  POLYGON ((151.19440168626 -33.79972582234, 151...
# 4115       None          1  POLYGON ((150.89283157887 -34.41386190014, 150...
# 1532  POINT (147.5117937338075 -34.44755058760544)            3.630592
# 2718  POINT (152.0354455407691 -29.08438715039074)            4.754356
# 4052  POINT (148.0550420635257 -35.73246106303703)            3.525041
# 3935  POINT (151.5124543825964 -30.65595772168708)            3.181999
# 3881   POINT (146.231953594896 -35.32213560762773)            4.961324
# 1812  POINT (147.3598320714941 -35.10816940381099)            4.029313
# 2997  POINT (144.3542427881058 -35.46528361494946)            6.909503
# 2151  POINT (151.7328615666218 -31.05144213816498)            2.487799
# 1336   POINT (148.0561970541727 -29.9798310009727)            4.505700
# 107    POINT (147.854758876725 -31.72949724619642)            3.904823
# 3612    POINT (151.2557647622885 -33.901329464432)            0.026304
# 250   POINT (148.9610954936047 -32.56564405903068)            2.609354
# 1616  POINT (142.0240223648466 -33.91972666013971)            8.817927
# 4105   POINT (151.200002014235 -33.80622474016224)            0.107236
# 4115   POINT (150.893060674628 -34.42781242440564)            0.595649
# 3743  POINT (151.2437907905973 -33.88692235846661)            0.028017
# 2654  POINT (151.4323302155062 -33.27641534180113)            0.653249
# 1704  POINT (148.3397044468835 -34.29814973425881)            2.771215
#
# [110 rows x 11 columns]

# %%
# burbs.plot()

# for idx, row in wanted_burbs.iterrows():
#     plt.annotate(s=row.NSW_LOCA_2, 
#                  xy=tuple(row.centroid.coords)[0],
#                  horizontalalignment='center')
# plt.title("Some pretty dodgy suburb names on a map");

# %%
right_here = shapely.geometry.point.Point(151.2299732, -33.9178754)
burbs["distance_from_UNSW"] = burbs.geometry.distance(right_here)

close_burbs = burbs[burbs.distance_from_UNSW<0.2]
close_burbs.plot()

# %%
right_here = shapely.geometry.point.Point(151.2299732, -33.9178754)
wanted_burbs["distance_from_UNSW"] = wanted_burbs.geometry.distance(right_here)

close_burbs = wanted_burbs[wanted_burbs.distance_from_UNSW<0.2]
close_burbs.plot()

for idx, row in wanted_burbs.iterrows():
    plt.annotate(s=row.NSW_LOCA_2, 
                 xy=tuple(row.centroid.coords)[0],
                 horizontalalignment='center')
plt.title("Some pretty dodgy suburb names on a map");

# %%
right_here = shapely.geometry.point.Point(151.2299732, -33.9178754)
burbs["distance_from_UNSW"] = burbs.geometry.distance(right_here)

close_burbs = burbs[burbs.distance_from_UNSW<0.2]
close_burbs.plot(color = 'white')

for idx, row in wanted_burbs.iterrows():
    plt.annotate(s=row.NSW_LOCA_2, 
                 xy=tuple(row.centroid.coords)[0],
                 horizontalalignment='center')
plt.title("suburbs around unsw");

# %%
test = burbs[burbs['NSW_LOCA_2'].isin(['BURWOOD','BANKSTOWN'])]
test

# %%
right_here = shapely.geometry.point.Point(151.2299732, -33.9178754)
test["distance_from_UNSW"] = test.geometry.distance(right_here)

test_burbs = test[test.distance_from_UNSW<0.2]
test_burbs.plot()

for idx, row in test.iterrows():
    plt.annotate(s=row.NSW_LOCA_2, 
                 xy=tuple(row.centroid.coords)[0],
                 horizontalalignment='center')
plt.title("Some pretty dodgy suburb names on a map");
